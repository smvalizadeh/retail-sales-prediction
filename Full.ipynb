# %%
import numpy as np
import pandas as pd
import re
import jdatetime
import datetime
import calendar

# %%
sale_df = pd.read_excel('P2-SalesData.xlsx')
sale_df.head()
# Out:
#        Date        Sales
# 0  14010115  1395.898445
# 1  14010114  1654.535199
# 2  14010113   767.028903
# 3  14010112  1323.005591
# 4  14010111  1294.524908

# %%
sale_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1111 entries, 0 to 1110
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1111 non-null   int64
#  1   Sales   1111 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 17.5 KB

# %%
def to_gregorian(datetime):
    datetime = int(datetime)
    return jdatetime.date(datetime//10000, datetime//100%100, datetime%100).togregorian()

# %%
sale_df['Date'] = sale_df['Date'].apply(to_gregorian)

# %%
sale_df['Date'] = pd.to_datetime(sale_df['Date'])
sale_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1111 entries, 0 to 1110
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1111 non-null   datetime64[ns]
#  1   Sales   1111 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 17.5 KB

# %%
def week_of_month(tgtdate):
    days_this_month = calendar.mdays[tgtdate.month]
    for i in range(1, days_this_month):
        d = datetime.datetime(tgtdate.year, tgtdate.month, i)
        if d.day - d.weekday() > 0:
            startdate = d
            break
    # now we canuse the modulo 7 appraoch
    return (tgtdate - startdate).days //7 + 1

# %%
# Create Cols
sale_df['Month Day'] = sale_df['Date'].dt.day
sale_df['Week Day'] = sale_df['Date'].dt.weekday
sale_df['Month'] = sale_df['Date'].dt.month
sale_df['Month Week'] = sale_df['Date'].apply(week_of_month)
sale_df['Year Week'] = sale_df['Date'].dt.weekofyear
sale_df['Year Day'] = sale_df['Date'].dt.dayofyear
# Out:
# d:\anaconda\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.

# %%
sale_df
# Out:
#            Date        Sales  Month Day  Week Day  Month  Month Week  \
# 0    2022-04-04  1395.898445          4         0      4           1
# 1    2022-04-03  1654.535199          3         6      4           0
# 2    2022-04-02   767.028903          2         5      4           0
# 3    2022-04-01  1323.005591          1         4      4           0
# 4    2022-03-31  1294.524908         31         3      3           4
# ...         ...          ...        ...       ...    ...         ...
# 1106 2019-03-25  1314.944083         25         0      3           4
# 1107 2019-03-24  1278.500591         24         6      3           3
# 1108 2019-03-23  1316.051583         23         5      3           3
# 1109 2019-03-22  1281.464259         22         4      3           3
# 1110 2019-03-21   358.654807         21         3      3           3
#
#       Year Week  Year Day
# 0            14        94
# 1            13        93
# 2            13        92
# 3            13        91
# 4            13        90
# ...         ...       ...
# 1106         13        84
# 1107         12        83
# 1108         12        82
# 1109         12        81
# 1110         12        80
#
# [1111 rows x 8 columns]

# %%
import keras
from keras.layers import Dense
from keras.layers import Dropout
from keras.models import Sequential
from keras.optimizers import Adam 
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
from keras.layers import LSTM
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
from keras import backend as K

# %%
train_set = sale_df.drop(axis=1, labels='Date')
train_set
# Out:
#             Sales  Month Day  Week Day  Month  Month Week  Year Week  Year Day
# 0     1395.898445          4         0      4           1         14        94
# 1     1654.535199          3         6      4           0         13        93
# 2      767.028903          2         5      4           0         13        92
# 3     1323.005591          1         4      4           0         13        91
# 4     1294.524908         31         3      3           4         13        90
# ...           ...        ...       ...    ...         ...        ...       ...
# 1106  1314.944083         25         0      3           4         13        84
# 1107  1278.500591         24         6      3           3         12        83
# 1108  1316.051583         23         5      3           3         12        82
# 1109  1281.464259         22         4      3           3         12        81
# 1110   358.654807         21         3      3           3         12        80
#
# [1111 rows x 7 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

# %%
scaled_train_set_x = scaler_x.fit_transform(train_set.drop(axis=1, labels='Sales'))
scaled_train_set_y = scaler_y.fit_transform(train_set[['Sales']])

# %%
scaled_train_set_x.shape
# Out:
# (1111, 6)

# %%
scaled_train_set_y.shape
# Out:
# (1111, 1)

# %%
train_x = []
train_y = []

n_past = 30

for i in range(n_past, len(scaled_train_set_x)):
    train_x.append(scaled_train_set_x[i - n_past:i])
    train_y.append(scaled_train_set_y[i][0])

train_x , train_y = np.array(train_x) , np.array(train_y)

# %%
train_x.shape
# Out:
# (1081, 30, 6)

# %%
def training_model(X_train, y_train, X_test, y_test):
    model = Sequential()
    model.add(LSTM(30, input_shape=(X_train.shape[1], X_train.shape[2]), activation='relu', return_sequences=False))
    model.add(Dropout(0.2))

    model.add(Dense(1))


    model.compile(loss = 'mean_squared_error', optimizer='adam')
    model.summary()

    callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    
    model.fit(X_train, y_train, epochs=500, batch_size=16, shuffle=True, callbacks=[callback], validation_data=(X_train[-100:], y_train[-100:]))

    prediction = model.predict(X_test)

    return mean_squared_error(y_true=y_test, y_pred=prediction), model

# %%
tscv = TimeSeriesSplit(n_splits = 3, test_size=100)
mse = []
for train_index, test_index in tscv.split(train_x):
    X_train, X_test = train_x[train_index], train_x[test_index]
    y_train, y_test = train_y[train_index], train_y[test_index]

    error, model = training_model(X_train, y_train, X_test, y_test)

    mse.append(error)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 30)                4440
#
#  dropout_3 (Dropout)         (None, 30)                0
#
#  dense_3 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 4,471
# Trainable params: 4,471
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 49/49 [==============================] - 2s 12ms/step - loss: 0.0446 - val_loss: 0.0347
# Epoch 2/500
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0165 - val_loss: 0.0274
# Epoch 3/500
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0132 - val_loss: 0.0307
# Epoch 4/500
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0141 - val_loss: 0.0365
# Epoch 5/500
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0122 - val_loss: 0.0228
# Epoch 6/500
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0113 - val_loss: 0.0262
# Epoch 7/500
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0108 - val_loss: 0.0255
# Epoch 8/500
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0113 - val_loss: 0.0267
# Epoch 9/500
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0108 - val_loss: 0.0228
# Epoch 10/500
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0107 - val_loss: 0.0236
# Epoch 11/500
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0100 - val_loss: 0.0243
# Epoch 12/500
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0105 - val_loss: 0.0230
# Epoch 13/500
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0095 - val_loss: 0.0223
# Epoch 14/500
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0094 - val_loss: 0.0239
# Epoch 15/500
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0091 - val_loss: 0.0217
# Epoch 16/500
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0094 - val_loss: 0.0253
# Epoch 17/500
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0097 - val_loss: 0.0212
# Epoch 18/500
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0095 - val_loss: 0.0243
# Epoch 19/500
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0094 - val_loss: 0.0251
# Epoch 20/500
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0093 - val_loss: 0.0227
# Epoch 21/500
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0090 - val_loss: 0.0244
# Epoch 22/500
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0091 - val_loss: 0.0221
# Epoch 23/500
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0089 - val_loss: 0.0220
# Epoch 24/500
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0086 - val_loss: 0.0225
# Epoch 25/500
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0085 - val_loss: 0.0208
# Epoch 26/500
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0083 - val_loss: 0.0251
# Epoch 27/500
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0090 - val_loss: 0.0204
# Epoch 28/500
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0085 - val_loss: 0.0195
# Epoch 29/500
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0082 - val_loss: 0.0185
# Epoch 30/500
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0086 - val_loss: 0.0198
# Epoch 31/500
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0087 - val_loss: 0.0214
# Epoch 32/500
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0083 - val_loss: 0.0215
# Epoch 33/500
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0081 - val_loss: 0.0233
# Epoch 34/500
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0080 - val_loss: 0.0221
# Epoch 35/500
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0079 - val_loss: 0.0206
# Epoch 36/500
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0078 - val_loss: 0.0270
# Epoch 37/500
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0079 - val_loss: 0.0223
# Epoch 38/500
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0080 - val_loss: 0.0232
# Epoch 39/500
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0080 - val_loss: 0.0213
# 4/4 [==============================] - 0s 4ms/step
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 30)                4440
#
#  dropout_4 (Dropout)         (None, 30)                0
#
#  dense_4 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 4,471
# Trainable params: 4,471
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 56/56 [==============================] - 2s 13ms/step - loss: 0.0311 - val_loss: 0.0083
# Epoch 2/500
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0166 - val_loss: 0.0060
# Epoch 3/500
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0149 - val_loss: 0.0106
# Epoch 4/500
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0136 - val_loss: 0.0060
# Epoch 5/500
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0128 - val_loss: 0.0140
# Epoch 6/500
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0124 - val_loss: 0.0112
# Epoch 7/500
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0115 - val_loss: 0.0087
# Epoch 8/500
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0115 - val_loss: 0.0044
# Epoch 9/500
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0113 - val_loss: 0.0105
# Epoch 10/500
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0102 - val_loss: 0.0072
# Epoch 11/500
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0107 - val_loss: 0.0053
# Epoch 12/500
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0104 - val_loss: 0.0077
# Epoch 13/500
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0104 - val_loss: 0.0079
# Epoch 14/500
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0097 - val_loss: 0.0077
# Epoch 15/500
# 56/56 [==============================] - 1s 9ms/step - loss: 0.0103 - val_loss: 0.0067
# Epoch 16/500
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0093 - val_loss: 0.0069
# Epoch 17/500
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0098 - val_loss: 0.0068
# Epoch 18/500
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0095 - val_loss: 0.0059
# 4/4 [==============================] - 0s 3ms/step
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 30)                4440
#
#  dropout_5 (Dropout)         (None, 30)                0
#
#  dense_5 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 4,471
# Trainable params: 4,471
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 62/62 [==============================] - 2s 11ms/step - loss: 0.0523 - val_loss: 0.0110
# Epoch 2/500
# 62/62 [==============================] - 1s 8ms/step - loss: 0.0171 - val_loss: 0.0077
# Epoch 3/500
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0150 - val_loss: 0.0087
# Epoch 4/500
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0142 - val_loss: 0.0086
# Epoch 5/500
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0126 - val_loss: 0.0090
# Epoch 6/500
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0117 - val_loss: 0.0093
# Epoch 7/500
# 62/62 [==============================] - 1s 9ms/step - loss: 0.0116 - val_loss: 0.0101
# Epoch 8/500
# 62/62 [==============================] - 1s 9ms/step - loss: 0.0120 - val_loss: 0.0086
# Epoch 9/500
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0118 - val_loss: 0.0106
# Epoch 10/500
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0111 - val_loss: 0.0098
# Epoch 11/500
# 62/62 [==============================] - 1s 8ms/step - loss: 0.0105 - val_loss: 0.0087
# Epoch 12/500
# 62/62 [==============================] - 1s 9ms/step - loss: 0.0116 - val_loss: 0.0098
# 4/4 [==============================] - 0s 3ms/step

# %% [markdown]
# Forecasting

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 30)                4440
#
#  dropout_2 (Dropout)         (None, 30)                0
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 4,471
# Trainable params: 4,471
# Non-trainable params: 0
# _________________________________________________________________

# %%
mse
# Out:
# [0.015193827493609697, 0.0075717436274011654, 0.011162105983504844]

# %%
print('Total Error: ', sum(mse) / 3)
# Out:
# Total Error:  0.011309225701505235

# %%
# Create dataset
prediction_df = pd.DataFrame({
    'Date': pd.date_range(end='2022-05-04', periods=30)})
prediction_df
# Out:
#          Date
# 0  2022-04-05
# 1  2022-04-06
# 2  2022-04-07
# 3  2022-04-08
# 4  2022-04-09
# 5  2022-04-10
# 6  2022-04-11
# 7  2022-04-12
# 8  2022-04-13
# 9  2022-04-14
# 10 2022-04-15
# 11 2022-04-16
# 12 2022-04-17
# 13 2022-04-18
# 14 2022-04-19
# 15 2022-04-20
# 16 2022-04-21
# 17 2022-04-22
# 18 2022-04-23
# 19 2022-04-24
# 20 2022-04-25
# 21 2022-04-26
# 22 2022-04-27
# 23 2022-04-28
# 24 2022-04-29
# 25 2022-04-30
# 26 2022-05-01
# 27 2022-05-02
# 28 2022-05-03
# 29 2022-05-04

# %%
# Create Cols
prediction_df['Month Day'] = prediction_df['Date'].dt.day
prediction_df['Week Day'] = prediction_df['Date'].dt.weekday
prediction_df['Month'] = prediction_df['Date'].dt.month
prediction_df['Month Week'] = prediction_df['Date'].apply(week_of_month)
prediction_df['Year Week'] = prediction_df['Date'].dt.weekofyear
prediction_df['Year Day'] = prediction_df['Date'].dt.dayofyear
# Out:
# d:\anaconda\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.

# %%
prediction_df
# Out:
#          Date  Month Day  Week Day  Month  Month Week  Year Week  Year Day
# 0  2022-04-05          5         1      4           1         14        95
# 1  2022-04-06          6         2      4           1         14        96
# 2  2022-04-07          7         3      4           1         14        97
# 3  2022-04-08          8         4      4           1         14        98
# 4  2022-04-09          9         5      4           1         14        99
# 5  2022-04-10         10         6      4           1         14       100
# 6  2022-04-11         11         0      4           2         15       101
# 7  2022-04-12         12         1      4           2         15       102
# 8  2022-04-13         13         2      4           2         15       103
# 9  2022-04-14         14         3      4           2         15       104
# 10 2022-04-15         15         4      4           2         15       105
# 11 2022-04-16         16         5      4           2         15       106
# 12 2022-04-17         17         6      4           2         15       107
# 13 2022-04-18         18         0      4           3         16       108
# 14 2022-04-19         19         1      4           3         16       109
# 15 2022-04-20         20         2      4           3         16       110
# 16 2022-04-21         21         3      4           3         16       111
# 17 2022-04-22         22         4      4           3         16       112
# 18 2022-04-23         23         5      4           3         16       113
# 19 2022-04-24         24         6      4           3         16       114
# 20 2022-04-25         25         0      4           4         17       115
# 21 2022-04-26         26         1      4           4         17       116
# 22 2022-04-27         27         2      4           4         17       117
# 23 2022-04-28         28         3      4           4         17       118
# 24 2022-04-29         29         4      4           4         17       119
# 25 2022-04-30         30         5      4           4         17       120
# 26 2022-05-01          1         6      5           0         17       121
# 27 2022-05-02          2         0      5           1         18       122
# 28 2022-05-03          3         1      5           1         18       123
# 29 2022-05-04          4         2      5           1         18       124

# %%
prediction_df[::-1]
# Out:
#          Date  Month Day  Week Day  Month  Month Week  Year Week  Year Day
# 29 2022-05-04          4         2      5           1         18       124
# 28 2022-05-03          3         1      5           1         18       123
# 27 2022-05-02          2         0      5           1         18       122
# 26 2022-05-01          1         6      5           0         17       121
# 25 2022-04-30         30         5      4           4         17       120
# 24 2022-04-29         29         4      4           4         17       119
# 23 2022-04-28         28         3      4           4         17       118
# 22 2022-04-27         27         2      4           4         17       117
# 21 2022-04-26         26         1      4           4         17       116
# 20 2022-04-25         25         0      4           4         17       115
# 19 2022-04-24         24         6      4           3         16       114
# 18 2022-04-23         23         5      4           3         16       113
# 17 2022-04-22         22         4      4           3         16       112
# 16 2022-04-21         21         3      4           3         16       111
# 15 2022-04-20         20         2      4           3         16       110
# 14 2022-04-19         19         1      4           3         16       109
# 13 2022-04-18         18         0      4           3         16       108
# 12 2022-04-17         17         6      4           2         15       107
# 11 2022-04-16         16         5      4           2         15       106
# 10 2022-04-15         15         4      4           2         15       105
# 9  2022-04-14         14         3      4           2         15       104
# 8  2022-04-13         13         2      4           2         15       103
# 7  2022-04-12         12         1      4           2         15       102
# 6  2022-04-11         11         0      4           2         15       101
# 5  2022-04-10         10         6      4           1         14       100
# 4  2022-04-09          9         5      4           1         14        99
# 3  2022-04-08          8         4      4           1         14        98
# 2  2022-04-07          7         3      4           1         14        97
# 1  2022-04-06          6         2      4           1         14        96
# 0  2022-04-05          5         1      4           1         14        95

# %%
final_test_df = pd.concat([prediction_df[::-1].drop(axis=1, labels='Date'), train_set.drop(axis=1, labels='Sales')], ignore_index=True)

# %%
out_put_x = scaler_x.transform(final_test_df)
out_put_x
# Out:
# array([[0.1       , 0.33333333, 0.36363636, 0.2       , 0.32692308,
#         0.3369863 ],
#        [0.06666667, 0.16666667, 0.36363636, 0.2       , 0.32692308,
#         0.33424658],
#        [0.03333333, 0.        , 0.36363636, 0.2       , 0.32692308,
#         0.33150685],
#        ...,
#        [0.73333333, 0.83333333, 0.18181818, 0.6       , 0.21153846,
#         0.22191781],
#        [0.7       , 0.66666667, 0.18181818, 0.6       , 0.21153846,
#         0.21917808],
#        [0.66666667, 0.5       , 0.18181818, 0.6       , 0.21153846,
#         0.21643836]])

# %%
out_put_x.shape
# Out:
# (1141, 6)

# %%
final_test_x = []

n_past = 30

for i in range(len(out_put_x)-2*n_past , len(out_put_x)-1*n_past):
    final_test_x.append(out_put_x[i : i + n_past])

final_test_x = np.array(final_test_x)

# %%
final_test_x.shape
# Out:
# (30, 30, 6)

# %%
final_test_y = model.predict(final_test_x)
# Out:
# 1/1 [==============================] - 0s 44ms/step

# %%
scaler_y.inverse_transform(final_test_y)
# Out:
# array([[1809.2671],
#        [1839.1765],
#        [1818.8552],
#        [1760.4587],
#        [1669.5164],
#        [1545.556 ],
#        [1633.1686],
#        [1697.9066],
#        [1733.7761],
#        [1719.2046],
#        [1648.9055],
#        [1540.1945],
#        [1400.8114],
#        [1494.7985],
#        [1571.3604],
#        [1620.5121],
#        [1611.1039],
#        [1538.0114],
#        [1414.6427],
#        [1272.272 ],
#        [1374.2333],
#        [1502.8148],
#        [1610.588 ],
#        [1683.0647],
#        [1703.4943],
#        [1682.0061],
#        [1627.0371],
#        [1738.5524],
#        [1817.0245],
#        [1864.4706]], dtype=float32)

# %%
model.save(r'D:\retail-sales-prediction\retailmodel.h5')

# %%
import pickle
with open(r'D:\retail-sales-prediction\retailmodel.mdl', 'wb') as fff:
    pickle.dump(model, fff, pickle.HIGHEST_PROTOCOL)
# Out:
# INFO:tensorflow:Assets written to: ram://1c0a5682-8d54-45e2-b3ee-f1895d46f86d/assets
